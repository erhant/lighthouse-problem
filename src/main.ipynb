# %%
import numpy as np
import matplotlib.pyplot as plt
from variation_1 import draw_match as match_1
from variation_2 import draw_match as match_2
# %matplotlib inline

# %%
N = 25
match_1(N)
# Out:
# Dark Area by Calculation: 545.4286083678343
# Dark Area by Theorem: 545.9578872753553
# (545.4286083678343, 545.9578872753553)

# %%
N = 13
match_2(N)
# Out:
# I: 1
# J: 0
# I 1 does not collide with J 0
